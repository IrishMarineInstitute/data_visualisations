# %%
# Prettymaps
from prettymaps import *
# Vsketch
# import vsketch
# OSMNX
import osmnx as ox
# Matplotlib-related
import matplotlib.font_manager as fm
from matplotlib import pyplot as plt
from descartes import PolygonPatch
# Shapely
from shapely.geometry import *
from shapely.affinity import *
from shapely.ops import unary_union

# %%
fig, ax = plt.subplots(figsize = (20, 20), constrained_layout = True)
palette = ['#28536B','#A69CAC','#D2E59E']
dilate = 0
background_c = '#f4e5cb'
layers = plot(
  #Centre the map center at 
  (53.2839064,-9.0837657),
  #Set radius for the map
  radius = 3500,
  ax=ax,
  #Name and select the various layers we want on the map
  #We want a square map so ensure that we're not querying for data in a circle
  layers = {
      #we want a square layout, so 
      'perimeter': {},
            'streets': {
                'width': {
                    'motorway': 5,
                    'trunk': 5,
                    'primary': 4.5,
                    'secondary': 4,
                    'tertiary': 3.5,
                    'cycleway': 3.5,
                    'residential': 3,
                    'service': 2,
                    'unclassified': 2,
                    'pedestrian': 2,
                    'footway': 1,
                },
                'circle': False, 'dilate': dilate
            },
            'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': True, 'circle': False, 'dilate': dilate},
            'water': {
                'tags':{
                    'waterway': True,
                    'water': True,
                    'harbour': True,
                    'marina': True,
                    'bay': True,
                    'river': True,
                    'sea' : True
                }, 
                'circle': False, 'dilate': dilate
            },
            'forest': {'tags': {'landuse': 'forest'}, 'circle': False, 'dilate': dilate},
            'green': {'tags': {'landuse': ['grass', 'orchard'], 'natural': ['island', 'wood'], 'leisure': 'park'}, 'circle': False, 'dilate': dilate},
            'beach': {'tags': {'natural': 'beach'}, 'circle': False, 'dilate': dilate},
            'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}, 'circle': False}
        },
        drawing_kwargs = {
            'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
            'background': {'fc': background_c, 'zorder': -1},
            'green': {'fc': '#8BB174', 'ec': '#2F3737', 'hatch_c': '#A7C497', 'hatch': 'ooo...', 'lw': 1, 'zorder': 1},
            'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 2},
            'water': {'fc': '#a8e1e6', 'ec': '#2F3737', 'hatch_c': '#9bc3d4', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
            'beach': {'fc': '#FCE19C', 'ec': '#2F3737', 'hatch_c': '#d4d196', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
            'parking': {'fc': background_c, 'ec': '#2F3737', 'lw': 1, 'zorder': 3},
            'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 4},
            'building': {'palette': palette, 'ec': '#2F3737', 'lw': .5, 'zorder': 5},
            'coastline': {'fc': '#a8e1e6', 'ec': '#2F3737', 'hatch_c': '#9bc3d4', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},

        },

        osm_credit = {'color': '#2F3737'}
)

# Set bounds
#xmin, ymin, xmax, ymax = layers['perimeter'].bounds
#dx, dy = xmax-xmin, ymax-ymin
#a = .2
#ax.set_xlim(xmin+a*dx, xmax-a*dx)
#ax.set_ylim(ymin+a*dy, ymax-a*dy)

#ax.text(
   #xmax-.35*dx, ymax+.02*dy,
    #"Kowloon Peninsula & Hong Kong Island",
    #color = '#2F3737',
    #fontproperties = fm.FontProperties(fname = '../assets/Permanent_Marker/PermanentMarker-Regular.ttf', size = 20),
#)

#Export a copy
plt.savefig('galway_2.png')
# Out:
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 5>()
#       3 dilate = 0
#       4 background_c = '#f4e5cb'
# ----> 5 layers = plot(
#       6   #Centre the map center at
#       7   (53.2839064,-9.0837657),
#       8   #Set radius for the map
#       9   radius = 3500,
#      10   ax=ax,
#      11   #Name and select the various layers we want on the map
#      12   #We want a square map so ensure that we're not querying for data in a circle
#      13   layers = {
#      14       #we want a square layout, so
#      15       'perimeter': {},
#      16             'streets': {
#      17                 'width': {
#      18                     'motorway': 5,
#      19                     'trunk': 5,
#      20                     'primary': 4.5,
#      21                     'secondary': 4,
#      22                     'tertiary': 3.5,
#      23                     'cycleway': 3.5,
#      24                     'residential': 3,
#      25                     'service': 2,
#      26                     'unclassified': 2,
#      27                     'pedestrian': 2,
#      28                     'footway': 1,
#      29                 },
#      30                 'circle': False, 'dilate': dilate
#      31             },
#      32             'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': True, 'circle': False, 'dilate': dilate},
#      33             'water': {
#      34                 'tags':{
#      35                     'waterway': True,
#      36                     'water': True,
#      37                     'harbour': True,
#      38                     'marina': True,
#      39                     'bay': True,
#      40                     'river': True,
#      41                     'sea' : True
#      42                 },
#      43                 'circle': False, 'dilate': dilate
#      44             },
#      45             'forest': {'tags': {'landuse': 'forest'}, 'circle': False, 'dilate': dilate},
#      46             'green': {'tags': {'landuse': ['grass', 'orchard'], 'natural': ['island', 'wood'], 'leisure': 'park'}, 'circle': False, 'dilate': dilate},
#      47             'beach': {'tags': {'natural': 'beach'}, 'circle': False, 'dilate': dilate},
#      48             'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}, 'circle': False}
#      49         },
#      50         drawing_kwargs = {
#      51             'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
#      52             'background': {'fc': background_c, 'zorder': -1},
#      53             'green': {'fc': '#8BB174', 'ec': '#2F3737', 'hatch_c': '#A7C497', 'hatch': 'ooo...', 'lw': 1, 'zorder': 1},
#      54             'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 2},
#      55             'water': {'fc': '#a8e1e6', 'ec': '#2F3737', 'hatch_c': '#9bc3d4', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
#      56             'beach': {'fc': '#FCE19C', 'ec': '#2F3737', 'hatch_c': '#d4d196', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
#      57             'parking': {'fc': background_c, 'ec': '#2F3737', 'lw': 1, 'zorder': 3},
#      58             'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 4},
#      59             'building': {'palette': palette, 'ec': '#2F3737', 'lw': .5, 'zorder': 5},
#      60             'coastline': {'fc': '#a8e1e6', 'ec': '#2F3737', 'hatch_c': '#9bc3d4', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
#      61
#      62         },
#      63
#      64         osm_credit = {'color': '#2F3737'}
#      65 )
#      67 # Set bounds
#      68 #xmin, ymin, xmax, ymax = layers['perimeter'].bounds
#      69 #dx, dy = xmax-xmin, ymax-ymin
#    (...)
#      80
#      81 #Export a copy
#      82 plt.savefig('galway_2.png')
#
# File /usr/local/lib/python3.9/site-packages/prettymaps/draw.py:230, in plot(query, backup, postprocessing, radius, layers, drawing_kwargs, osm_credit, figsize, ax, title, vsketch, x, y, scale_x, scale_y, rotation)
#     223     base_kwargs = {
#     224         "perimeter": query
#     225         if query_mode == "polygon"
#     226         else get_perimeter(query, by_osmid=query_mode == "osmid")
#     227     }
#     229 # Fetch layers
# --> 230 layers = {
#     231     layer: get_layer(
#     232         layer, **base_kwargs, **(kwargs if type(kwargs) == dict else {})
#     233     )
#     234     for layer, kwargs in layers.items()
#     235 }
#     237 # Apply transformation to layers (translate & scale)
#     238 layers = transform(layers, x, y, scale_x, scale_y, rotation)
#
# File /usr/local/lib/python3.9/site-packages/prettymaps/draw.py:231, in <dictcomp>(.0)
#     223     base_kwargs = {
#     224         "perimeter": query
#     225         if query_mode == "polygon"
#     226         else get_perimeter(query, by_osmid=query_mode == "osmid")
#     227     }
#     229 # Fetch layers
#     230 layers = {
# --> 231     layer: get_layer(
#     232         layer, **base_kwargs, **(kwargs if type(kwargs) == dict else {})
#     233     )
#     234     for layer, kwargs in layers.items()
#     235 }
#     237 # Apply transformation to layers (translate & scale)
#     238 layers = transform(layers, x, y, scale_x, scale_y, rotation)
#
# File /usr/local/lib/python3.9/site-packages/prettymaps/fetch.py:380, in get_layer(layer, **kwargs)
#     378 # Fetch streets or railway
#     379 if layer in ["streets", "railway", "waterway"]:
# --> 380     return get_streets(**kwargs, layer=layer)
#     381 # Fetch Coastline
#     382 elif layer == "coastline":
#
# File /usr/local/lib/python3.9/site-packages/prettymaps/fetch.py:285, in get_streets(perimeter, point, radius, layer, width, custom_filter, buffer, retain_all, circle, dilate, truncate_by_edge)
#     282 elif (point is not None) and (radius is not None):
#     283     # Fetch streets data, save CRS & project
#     284     try:
# --> 285         streets = ox.graph_from_point(
#     286             point,
#     287             dist=radius + dilate + buffer,
#     288             retain_all=retain_all,
#     289             custom_filter=custom_filter,
#     290             truncate_by_edge = truncate_by_edge,
#     291         )
#     292         crs = ox.graph_to_gdfs(streets, nodes=False).crs
#     293         streets = ox.project_graph(streets)
#
# File /usr/local/lib/python3.9/site-packages/osmnx/graph.py:156, in graph_from_point(center_point, dist, dist_type, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     153 north, south, east, west = utils_geo.bbox_from_point(center_point, dist)
#     155 # create a graph from the bounding box
# --> 156 G = graph_from_bbox(
#     157     north,
#     158     south,
#     159     east,
#     160     west,
#     161     network_type=network_type,
#     162     simplify=simplify,
#     163     retain_all=retain_all,
#     164     truncate_by_edge=truncate_by_edge,
#     165     clean_periphery=clean_periphery,
#     166     custom_filter=custom_filter,
#     167 )
#     169 # if network dist_type is network, find the node in the graph nearest to
#     170 # the center point, and truncate the graph by network distance from node
#     171 if dist_type == "network":
#
# File /usr/local/lib/python3.9/site-packages/osmnx/graph.py:81, in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#      78 polygon = utils_geo.bbox_to_poly(north, south, east, west)
#      80 # create graph using this polygon geometry
# ---> 81 G = graph_from_polygon(
#      82     polygon,
#      83     network_type=network_type,
#      84     simplify=simplify,
#      85     retain_all=retain_all,
#      86     truncate_by_edge=truncate_by_edge,
#      87     clean_periphery=clean_periphery,
#      88     custom_filter=custom_filter,
#      89 )
#      91 utils.log(f"graph_from_bbox returned graph with {len(G)} nodes and {len(G.edges)} edges")
#      92 return G
#
# File /usr/local/lib/python3.9/site-packages/osmnx/graph.py:440, in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     433     G_buff = simplification.simplify_graph(G_buff)
#     435 # truncate graph by original polygon to return graph within polygon
#     436 # caller wants. don't simplify again: this allows us to retain
#     437 # intersections along the street that may now only connect 2 street
#     438 # segments in the network, but in reality also connect to an
#     439 # intersection just outside the polygon
# --> 440 G = truncate.truncate_graph_polygon(G_buff, polygon, retain_all, truncate_by_edge)
#     442 # count how many physical streets in buffered graph connect to each
#     443 # intersection in un-buffered graph, to retain true counts for each
#     444 # intersection, even if some of its neighbors are outside the polygon
#     445 spn = utils_graph.count_streets_per_node(G_buff, nodes=G.nodes)
#
# File /usr/local/lib/python3.9/site-packages/osmnx/truncate.py:188, in truncate_graph_polygon(G, polygon, retain_all, truncate_by_edge, quadrat_width, min_num)
#     185 if not retain_all:
#     186     # remove any isolated nodes and retain only the largest component
#     187     G = utils_graph.remove_isolated_nodes(G)
# --> 188     G = utils_graph.get_largest_component(G)
#     190 utils.log("Truncated graph by polygon")
#     191 return G
#
# File /usr/local/lib/python3.9/site-packages/osmnx/utils_graph.py:346, in get_largest_component(G, strongly)
#     343     n = len(G)
#     345     # induce (frozen) subgraph then unfreeze it by making new MultiDiGraph
# --> 346     G = nx.MultiDiGraph(G.subgraph(largest_cc))
#     347     utils.log(f"Got largest {kind} connected component ({len(G)} of {n} total nodes)")
#     349 return G
#
# File /usr/local/lib/python3.9/site-packages/networkx/classes/multidigraph.py:346, in MultiDiGraph.__init__(self, incoming_graph_data, multigraph_input, **attr)
#     344         DiGraph.__init__(self, incoming_graph_data, **attr)
#     345 else:
# --> 346     DiGraph.__init__(self, incoming_graph_data, **attr)
#
# File /usr/local/lib/python3.9/site-packages/networkx/classes/digraph.py:319, in DiGraph.__init__(self, incoming_graph_data, **attr)
#     317 # attempt to load graph with data
#     318 if incoming_graph_data is not None:
# --> 319     convert.to_networkx_graph(incoming_graph_data, create_using=self)
#     320 # load graph attributes (must be after convert)
#     321 self.graph.update(attr)
#
# File /usr/local/lib/python3.9/site-packages/networkx/convert.py:75, in to_networkx_graph(data, create_using, multigraph_input)
#      73 if hasattr(data, "adj"):
#      74     try:
# ---> 75         result = from_dict_of_dicts(
#      76             data.adj,
#      77             create_using=create_using,
#      78             multigraph_input=data.is_multigraph(),
#      79         )
#      80         # data.graph should be dict-like
#      81         result.graph.update(data.graph)
#
# File /usr/local/lib/python3.9/site-packages/networkx/convert.py:398, in from_dict_of_dicts(d, create_using, multigraph_input)
#     396 if G.is_directed():
#     397     if G.is_multigraph():
# --> 398         G.add_edges_from(
#     399             (u, v, key, data)
#     400             for u, nbrs in d.items()
#     401             for v, datadict in nbrs.items()
#     402             for key, data in datadict.items()
#     403         )
#     404     else:
#     405         G.add_edges_from(
#     406             (u, v, data)
#     407             for u, nbrs in d.items()
#     408             for v, datadict in nbrs.items()
#     409             for key, data in datadict.items()
#     410         )
#
# File /usr/local/lib/python3.9/site-packages/networkx/classes/multigraph.py:562, in MultiGraph.add_edges_from(self, ebunch_to_add, **attr)
#     511 """Add all the edges in ebunch_to_add.
#     512
#     513 Parameters
#    (...)
#     559 >>> G.add_edges_from([(3, 4), (1, 4)], label="WN2898")
#     560 """
#     561 keylist = []
# --> 562 for e in ebunch_to_add:
#     563     ne = len(e)
#     564     if ne == 4:
#
# File /usr/local/lib/python3.9/site-packages/networkx/convert.py:401, in <genexpr>(.0)
#     396 if G.is_directed():
#     397     if G.is_multigraph():
#     398         G.add_edges_from(
#     399             (u, v, key, data)
#     400             for u, nbrs in d.items()
# --> 401             for v, datadict in nbrs.items()
#     402             for key, data in datadict.items()
#     403         )
#     404     else:
#     405         G.add_edges_from(
#     406             (u, v, data)
#     407             for u, nbrs in d.items()
#     408             for v, datadict in nbrs.items()
#     409             for key, data in datadict.items()
#     410         )
#
# File /usr/local/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/_collections_abc.py:850, in ItemsView.__iter__(self)
#     849 def __iter__(self):
# --> 850     for key in self._mapping:
#     851         yield (key, self._mapping[key])
#
# File /usr/local/lib/python3.9/site-packages/networkx/classes/coreviews.py:392, in FilterMultiInner.__iter__(self)
#     390 else:
#     391     my_nodes = (n for n in self._atlas if self.NODE_OK(n))
# --> 392 for n in my_nodes:
#     393     some_keys_ok = False
#     394     for key in self._atlas[n]:
#
# KeyboardInterrupt:

# %%
palette = ['#FFC857', '#E9724C', '#C5283D']

fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True)

def postprocessing(layers):
    boundary = Polygon(layers['green'].buffer(5)[0].exterior).buffer(0)
    layers['building'] = layers['building'].buffer(0).intersection(boundary)
    layers['streets'] = layers['streets'].buffer(0).intersection(boundary)
    return layers

layers = plot(
    'palmanova, Italy', radius = 970,
    
    ax = ax,

    postprocessing = postprocessing,
    
    layers = {
            'perimeter': {},
            'streets': {
                'width': {
                    'motorway': 5,
                    'trunk': 5,
                    'primary': 4.5,
                    'secondary': 4,
                    'tertiary': 3.5,
                    'residential': 3,
                    'service': 2,
                    'unclassified': 2,
                    'pedestrian': 2,
                    'footway': 1,
                    'track': 1,
                    'bridleway': 1
                }
            },
            'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': False},
            'water': {'tags': {'natural': ['water', 'bay']}},
            'green': {'tags': {'landuse': 'grass', 'natural': ['island', 'wood'], 'leisure': 'park'}},
            'scrub': {'tags': {'natural': 'scrub'}},
            'walls': {'tags': {'historic': 'citywalls'}},
            'pedestrian_way': {'tags': {'highway': 'pedestrian'}},
        },
        drawing_kwargs = {
            'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},
            'perimeter': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'lw': 0, 'hatch': 'ooo...',  'zorder': 0},
            'green': {'fc': '#D0F1BF', 'ec': '#2F3737', 'hatch_c': '#b3cfa5', 'hatch': 'ooo...', 'lw': 1, 'zorder': 1},
            'scrub': {'fc': '#89d689', 'ec': '#2F3737', 'hatch_c': '#75bd75', 'hatch': 'ooo...', 'lw': 1, 'zorder': 1},
            'water': {'fc': '#a1e3ff', 'ec': '#2F3737', 'lw': 1, 'zorder': 2},
            'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},
            'walls': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},
            'building': {'palette': palette, 'ec': '#2F3737', 'lw': .5, 'zorder': 4},
            'pedestrian_way': {'fc': '#dfe8d3', 'ec': '#2F3737', 'lw': 1, 'zorder': 4},
        },

        osm_credit = {'color': '#2F3737'}
)

plt.savefig('palmanova.png')
# Out:
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.9/site-packages/prettymaps/fetch.py:317: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   list(lines)
# /usr/local/lib/python3.9/site-packages/prettymaps/fetch.py:317: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   list(lines)
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /usr/local/lib/python3.9/site-packages/osmnx/geometries.py:798: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_inner_linestring in list(merged_inner_linestrings):
# /usr/local/lib/python3.9/site-packages/osmnx/geometries.py:798: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_inner_linestring in list(merged_inner_linestrings):
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.9/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:

# %%
# General style parameters
palette = ['#433633', '#FF5E5B']
background_c = '#F2F4CB'
dilate = 100

# Setup plot
fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True)

layers = plot(
    'Munster, Ontario, Canada', radius = 1500,
    ax = ax,
    
    layers = {
            'perimeter': {},
            'streets': {
                'width': {
                    'motorway': 5,
                    'trunk': 5,
                    'primary': 4.5,
                    'secondary': 4,
                    'tertiary': 3.5,
                    'cycleway': 3.5,
                    'residential': 3,
                    'service': 2,
                    'unclassified': 2,
                    'pedestrian': 2,
                    'footway': 1,
                },
                'circle': False, 'dilate': dilate
            },
            'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': True, 'circle': False, 'dilate': dilate},
            'water': {'tags': {'natural': ['water', 'bay']}, 'circle': False, 'dilate': dilate},
            'forest': {'tags': {'landuse': 'forest'}, 'circle': False, 'dilate': dilate},
            'green': {'tags': {'landuse': ['grass', 'orchard'], 'natural': ['island', 'wood'], 'leisure': 'park'}, 'circle': False, 'dilate': dilate},
            'beach': {'tags': {'natural': 'beach'}, 'circle': False, 'dilate': dilate},
            'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}, 'circle': False}
        },
        drawing_kwargs = {
            'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
            'background': {'fc': background_c, 'zorder': -1},
            'green': {'fc': '#8BB174', 'ec': '#2F3737', 'hatch_c': '#A7C497', 'hatch': 'ooo...', 'lw': 1, 'zorder': 1},
            'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 2},
            'water': {'fc': '#a8e1e6', 'ec': '#2F3737', 'hatch_c': '#9bc3d4', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
            'beach': {'fc': '#FCE19C', 'ec': '#2F3737', 'hatch_c': '#d4d196', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
            'parking': {'fc': background_c, 'ec': '#2F3737', 'lw': 1, 'zorder': 3},
            'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 4},
            'building': {'palette': palette, 'ec': '#2F3737', 'lw': .5, 'zorder': 5},
            
        },

#         osm_credit = {'x': .405, 'y': .68, 'color': '#2F3737'}
)

# Set bounds
xmin, ymin, xmax, ymax = layers['perimeter'].bounds
dx, dy = xmax-xmin, ymax-ymin
a = .2
ax.set_xlim(xmin+a*dx, xmax-a*dx)
ax.set_ylim(ymin+a*dy, ymax-a*dy)

# ax.text(
#     xmin+.39*dx, ymin+.305*dy,
#     ' '*3 + 'Stad van de Zon,\nHeerhugowaard, Netherlands',
#     color = '#2F3737',
#     zorder = 6, rotation = +1.75,
#     fontproperties = fm.FontProperties(fname = '../assets/Permanent_Marker/PermanentMarker-Regular.ttf', size = 24)
# )

plt.savefig('heerhugowaard.png')
#plt.savefig('../prints/heerhugowaard.svg')
