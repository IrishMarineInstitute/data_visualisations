# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 2000
import pandas as pd
import numpy as np
from PIL import Image

# %%
#if you want to use an url as the source: 

#data = pd.read_html(input("paste your URL here: "))

data = open("../data/winnie.txt").read()
#you want to make sure it's all string
data = str(data)
#then you can generate the first wordcloud to check it's all ok
wordcloud = WordCloud().generate(data)
#and use matplotlib to display generated image
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
cloud_mask = np.array(Image.open("/Users/macbon/Desktop/ac_fh.png"))
plt.imshow(cloud_mask)
plt.axis("off")
# make sure each stage works before proceeding
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 cloud_mask = np.array(Image.open("/Users/macbon/Desktop/ac_fh.png"))
#       2 plt.imshow(cloud_mask)
#       3 plt.axis("off")
#
# File /usr/local/lib/python3.9/site-packages/PIL/Image.py:3068, in open(fp, mode, formats)
#    3065     filename = fp
#    3067 if filename:
# -> 3068     fp = builtins.open(filename, "rb")
#    3069     exclusive_fp = True
#    3071 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/macbon/Desktop/ac_fh.png'

# %%
data = open("../data/Terry-Pratchett-The-Amazing-Maurice-and-His-Educated-Rodents.txt").read()
#you want to make sure it's all string
data = str(data)
stopwords=STOPWORDS
stopwords.update(["said", "say"])
wordcloud = WordCloud(font_path="../font/IMFellDWPicaSC-Regular.ttf", #add your font here
                      width = 2380, # use the same width and height
                                    #as your mask size for best
                                    #results
                      height = 2879,
                      stopwords=STOPWORDS, #if the staple stopwords
                                           #the module provides is
                                           #not good enough, you can
                                           #list your own
                      background_color = "white",
                      mask = cloud_mask,
                      contour_width = 0,
                      repeat=True,
                      min_font_size = 0.01 #if you want a tight fit,
                                         #go for a small figure here
#                       ,max_words = 1000, #set max words count
                      ).generate(data)

image_colors = ImageColorGenerator(cloud_mask) 
#use the mask colours
wordcloud.generate(data)
wordcloud.recolor(color_func=image_colors)
plt.imshow(wordcloud)
plt.axis("off")
fig1=plt.gcf()
plt.show()
plt.draw()
# fig1.savefig("Woolf.svg", format="svg", bbox_inches="tight")
